# %% [markdown]
# ```
#  pip install tree-sitter tree-sitter-cuda
#  ```

# %%
import tree_sitter_cuda, tree_sitter_cpp
from tree_sitter import Language, Parser, Query, QueryCursor
import jz_codetools.parse as parse
import jz_codetools.generator as gen

CUDA = Language(tree_sitter_cuda.language())
CPP = Language(tree_sitter_cpp.language())
parser = Parser(CUDA)

# %load_ext autoreload
# %autoreload 2

# %%
file = "../custom_jax_cuda/fmm.cuh"

kernels = parse.get_functions_from_file(file, only_kernels=True, names=["TestPositions", "SimpleArange"])

kernels["TestPositions"].template_par["p"].instances = [0,1,2,3]


# outfile = "../custom_jax_cuda/generated/ffi_fmm.cu"
# gen.generate_ffi_module_file(outfile, kernels, includes = ["../fmm.cuh"])

# module_code = gen.create_ffi_module_code(kernels, includes)

# outfile = "../custom_jax_cuda/generated/ffi_fmm.cu"
# with open(outfile, 'w') as f:
#     f.write(module_code)

# %%
# myfunc = tuple(filter(lambda f: f.name == "MySimpleKernel", funcs))[0]
# myfunc = funcs["TestPositions"]
# myfunc.template_par[0].instances = [0,1,2,3]

# print(create_ffi_call(myfunc))
